# %%
import math 
from numpy import mean
from numpy import std
import pandas as pd
import yahoo_fin.stock_info as si
import yfinance as yf
from matplotlib import pyplot



# cov(X, Y) = (sum (x - mean(X)) * (y - mean(Y)) ) * 1/(n-1)


ticker = yf.Ticker("AAPL")
ticker2 = yf.Ticker("^GSPC")



appl_hist = ticker.history(period='5y')
sp500_hist = ticker2.history(period='5y')

print(mean(appl_hist), std(appl_hist))
print(mean(sp500_hist), std(sp500_hist))
# plot
pyplot.scatter(appl_hist, sp500_hist)
pyplot.show()
# Out:
# /Users/callumthomas/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3472: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# Open            8.559960e+01
# High            8.659731e+01
# Low             8.463623e+01
# Close           8.565367e+01
# Volume          1.195811e+08
# Dividends       3.099682e-03
# Stock Splits    3.177125e-03
# dtype: float64 Open            4.599926e+01
# High            4.658872e+01
# Low             4.539204e+01
# Close           4.600495e+01
# Volume          5.499856e+07
# Dividends       2.454304e-02
# Stock Splits    1.126872e-01
# dtype: float64
# Open            3.308113e+03
# High            3.326613e+03
# Low             3.287462e+03
# Close           3.308129e+03
# Volume          3.903914e+09
# Dividends       0.000000e+00
# ...

# %%
df = pd.DataFrame(appl_hist)
df2 = pd.DataFrame(sp500_hist)

df.head()
# Out:
#                  Open       High        Low      Close     Volume  Dividends  \
# Date
# 2017-06-28  34.195945  34.579343  33.881178  34.513077   88329600        0.0
# 2017-06-29  34.248019  34.347419  33.672918  34.004250  125997600        0.0
# 2017-06-30  34.186474  34.307176  34.027908  34.084709   92096400        0.0
# 2017-07-03  34.288252  34.387651  33.866986  33.961651   57111200        0.0
# 2017-07-05  34.006611  34.266942  33.777044  34.101276   86278400        0.0
#
#             Stock Splits
# Date
# 2017-06-28           0.0
# 2017-06-29           0.0
# 2017-06-30           0.0
# 2017-07-03           0.0
# 2017-07-05           0.0

# %%
df2.head()
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2017-06-28  2428.699951  2442.969971  2428.020020  2440.689941  3500800000
# 2017-06-29  2442.379883  2442.729980  2405.699951  2419.699951  3900280000
# 2017-06-30  2429.199951  2432.709961  2421.649902  2423.409912  3361590000
# 2017-07-03  2431.389893  2439.169922  2428.689941  2429.010010  1962290000
# 2017-07-05  2430.780029  2434.899902  2422.050049  2432.540039  3367220000
#
#             Dividends  Stock Splits
# Date
# 2017-06-28          0             0
# 2017-06-29          0             0
# 2017-06-30          0             0
# 2017-07-03          0             0
# 2017-07-05          0             0

# %%
# print the ammount of not null values in the dataframe
print("df1: ", df.isnull().sum())
print("df2: ", df2.isnull().sum())
# Out:
# df1:  Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64
# df2:  Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64

# %%
aapl_mean_high_array = df['High']
aapl_mean_low_array = df['Low']
sp500_mean_high_array = df2['High']
sp500_mean_low_array = df2['Low']

print ("aapl_mean_high_array: ", aapl_mean_high_array)
# Out:
# aapl_mean_high_array:  Date
# 2017-06-28     34.579343
# 2017-06-29     34.347419
# 2017-06-30     34.307176
# 2017-07-03     34.387651
# 2017-07-05     34.266942
#                  ...
# 2022-06-22    137.759995
# 2022-06-23    138.589996
# 2022-06-24    141.910004
# 2022-06-27    143.490005
# 2022-06-28    143.421997
# Name: High, Length: 1259, dtype: float64
